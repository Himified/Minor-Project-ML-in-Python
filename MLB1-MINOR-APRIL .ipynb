# %% [markdown]
# # <font color='green'>STUDENTS PERFORMANCE: DATA ANALYSIS</font>

# %% [markdown]
# **<font color='florecent'>Objective:**
# <font color='purple'>To understand how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course).</font>

# %% [markdown]
# **<font color='purple'>By:- Himani Verma</font>**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ex= pd.read_csv('StudentsPerformance.csv')
ex.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ***Lets check the data type of each coulmn and Non- Null Count..***

# %%
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
ex.shape
# Out:
# (1000, 8)

# %%
ex.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ***Clearly tells the average class performance and min and max marks obtained by the Students...***

# %% [markdown]
# ***Lets see the sex ratio of students..***

# %%
ex['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ***Clearly female Students are more then Male students***

# %% [markdown]
# ***Lets check for any missing data***

# %%
ex.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ***As ex.info() already showed the Non-Null values this confirms that there are no missing values in the data.***

# %% [markdown]
# ***For Analysing the data well lets count the factors that plays a mojor role in performance of Students***

# %%
ex['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# ***Majority of Students belong to Group C and minority belongs to Group A.***

# %%
per=ex.groupby('race/ethnicity')

# %%
per.mean()
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %% [markdown]
# ***As we can see among all race/ethnicity the performance of Group E is the best and with Group A (minority) with the poor performance whrn compared to the rest.***

# %% [markdown]
# ***Lets now see the Parental level of Education***

# %%
ex['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
ex['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
edu= ex.groupby('parental level of education')

# %%
edu.mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %% [markdown]
# ***This clearly says Students whose parents have just studied till High School have performed not good when compared to others.And students whose parents hold Masters degree have performed well.***

# %% [markdown]
# ***Lets now see how the test prepation has to show in the results of Students.***

# %%
ex['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# ***So many were not able to complete the Syllabus by time.***

# %%
tes= ex.groupby('test preparation course')
tes.mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %%
ex['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %% [markdown]
# ***One third of Students had free/reduced lunch***

# %% [markdown]
# ***Students who completed the syllabus on time have no doubt performed well.***

# %% [markdown]
# ***Now lets Analyse the Total Score of Each Students and average score.***

# %%
ex['Total Score']=ex['math score']+ex['reading score']+ex['writing score']
ex['Average Score']=(ex['math score']+ex['reading score']+ex['writing score'])/3

# %%
ex.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score  Average Score  Grdae A
# 0          218      72.666667    False
# 1          247      82.333333    False
# ...

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(ex['Average Score'], bins=35 ,color='green')

# %% [markdown]
# ***Rug plot without kde analysis for the same.***

# %%
sns.distplot(ex['Average Score'], bins=35, kde=False,rug=True ,color='red')

# %% [markdown]
# ***Analysing reading writing and math score indiviually through histogram.***

# %%
fig, axes= plt.subplots(1, 3, figsize=(12, 4))
axes[0].hist(x='math score', data=ex, bins=30, color='orange')
axes[0].set_title('Math Score')

axes[1].hist(x='reading score', data=ex, bins=30, color='red')
axes[1].set_title('Reading Score')

axes[2].hist(x='writing score', data=ex, bins=30, color='pink')
axes[2].set_title('Writing Score')
# Out:
# Text(0.5, 1.0, 'Writing Score')

# %% [markdown]
# - The average total score of students ranges mostly betweem 50 to 80.
# - Maximum number of students have marks between 60 to 80 in all three subjects.
# - The students in writing have greater consistency of marks between 60 to 80.

# %%
sns.heatmap(ex.corr(), cmap='magma')

# %% [markdown]
# ***Each pair correlated using heatmap.***

# %% [markdown]
# ***Lets see the marks scored by each Gender.***

# %%
sns.barplot(x='gender', data=ex, y='Average Score', hue='gender', dodge=False, palette='magma')
plt.title('Gender V/S Marks')
# Out:
# Text(0.5, 1.0, 'Gender V/S Marks')

# %% [markdown]
# - Marks Scored by Females are more than males.
# - Average Score of Females range is approx 70.
# - Average Score of Males is between 60 and 70

# %% [markdown]
# ***Gender V/s Marks scored in each subject***

# %%
plt.subplot(1,3,1)
sns.violinplot(x='gender', y='math score', data=ex, palette='magma')
plt.subplot(1,3,2)
sns.violinplot(x='gender', y='reading score', data=ex, palette='magma')
plt.subplot(1,3,3)
sns.violinplot(x='gender', y='writing score', data=ex, palette='magma')

plt.tight_layout()

# %% [markdown]
# - It is Quite clear to state the Females have Scored more marks in indiviual subject.

# %% [markdown]
# ***Lets see how many students are fail in each subject***

# %%
ex['math_pass']=ex['math score']>= 40
ex['math_pass'].value_counts()
# Out:
# True     960
# False     40
# Name: math_pass, dtype: int64

# %% [markdown]
# ***So if the passing Criteria is kept 40 then 40 Students are failed in math.***

# %%
ex['reading_pass']=ex['reading score']>= 40
ex['reading_pass'].value_counts()
# Out:
# True     974
# False     26
# Name: reading_pass, dtype: int64

# %%
ex['writing_pass']=ex['writing score']>= 40
ex['writing_pass'].value_counts()
# Out:
# True     968
# False     32
# Name: writing_pass, dtype: int64

# %% [markdown]
# ***Similarly 26 Students are failing in reading and 32 are failing in writing.***

# %% [markdown]
# ***Analysing Test Prepartion course with average score***

# %%
fig=plt.figure(figsize=(12,6))
ax=fig.add_subplot(1,2,1)
sns.boxplot(x='test preparation course',y='Average Score',data=ex, palette='coolwarm')
ax=fig.add_subplot(1,2,2)
sns.swarmplot(x='test preparation course',y='Average Score',data=ex, palette='magma')

# %% [markdown]
# - The mean total score of girls is greater than that of the boys.
# - The average marks of females in maths is less than male students.
# - The average marks of females are greater in reading and writing than males.
# - As seen earlier, number of students who completed their test preparation course are less than those who didn't.
# -  Also those students who completed their course before the exam have a greater average total score.
# -  Among those who completed their course, females have a greater average score than males.
# -  From these we can assume that females are more sincere towards studies than males.

# %% [markdown]
# # ***Count Plot***

# %% [markdown]
# ***Race/ethnicity of each group***

# %%
fig= plt.figure(figsize=(12,6))
ax=fig.add_subplot(1,2,1)
sns.countplot(x='race/ethnicity', data=ex, hue='gender')
ax=fig.add_subplot(1,2,2)
sns.countplot(x='race/ethnicity', data=ex)

# %% [markdown]
# - Group C is in majority and Group A minority.
# - Females of Group C holds more popuplation.
# - Females of Group A holds least population

# %% [markdown]
# ***Parental level of education Count***

# %%
fig= plt.figure(figsize=(20,6))
ax=fig.add_subplot(1,2,1)
sns.countplot(x='parental level of education', data=ex, hue='gender')
ax=fig.add_subplot(1,2,2)
sns.countplot(x='parental level of education', data=ex)
plt.tight_layout()

# %% [markdown]
# - There are many Students whose mothers are graduate from some College.
# - there are very few students whose fathers hold Masters degree

# %% [markdown]
# ***Lunch Count***

# %%
fig= plt.figure(figsize=(12,6))
ax=fig.add_subplot(1,2,1)
sns.countplot(x='lunch', data=ex, hue='gender')
ax=fig.add_subplot(1,2,2)
sns.countplot(x='lunch', data=ex)

# %% [markdown]
# **Race/ethnicity V/S average marks***

# %%
sns.violinplot(x='race/ethnicity',y='Average Score',palette='magma',data=ex,hue='gender',split=True)

# %% [markdown]
# -  The maximum number of students belong to group C and minimum from group A. This shows that group C has greater awareness about importance of education.
# -  The number of female students in group B and C are greater than male students. The count of male and female students are almost equal in group E and D. This shows females are being given equal opprtunities as males.
# -  Performance of group E is the best from which we can assume that it has got a lot of potential students.This urges the requirement to promote more students into academics from the group.
# -  Performance of females is at par with the males in all the groups.

# %% [markdown]
# ***Parental education V/S average marks***

# %%
fig=plt.figure(figsize=(20,6))
ax=fig.add_subplot(1,2,1)
sns.stripplot(x='parental level of education',y='Average Score',data=ex, palette='coolwarm')
ax=fig.add_subplot(1,2,2)
sns.barplot(x='parental level of education',y='Average Score',data=ex, palette='magma')

# %% [markdown]
# - We can assume parents with more education can have a child who scores more marks.
# - Students who scored more marks are those whose parents hold masters degree.
# - Students with less marks are those whose parents just studied till high school.

# %% [markdown]
# ***Lunch V/S average score***

# %%
fig=plt.figure(figsize=(12,6))
ax=fig.add_subplot(1,2,1)
sns.stripplot(x='lunch',y='Average Score',data=ex, palette='coolwarm')
ax=fig.add_subplot(1,2,2)
sns.barplot(x='lunch',y='Average Score',data=ex, palette='magma')

# %% [markdown]
# -  We can assume that only students who demonstrate financial need are able to get free/reduced price lunches.
# -  Students from standard lunch category are greater than the free/reduced price category
# -  Number of females in both free/reduced price category and the stadard category is greater than the males.
# -  On an average, the students who are in this program have lower average test scores than those who do not demonstrate this financial need.

# %% [markdown]
# ***Count of females based on parental level of education***

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1, 1, 1)
plt.title('Count of females based on parental level of education')
sns.countplot(ex[ex['gender']=='female']['parental level of education'],data=ex,palette='magma')

# %% [markdown]
# - From the graphs it is quite clear that the more post high-school education the parent has received, the better their child performs on these tests.
# - Those children with their parents having school level education have relatively lower overall percentage. The seriousness in studies of a student depends on the parental background of education.
# -  We can assume that students coming from families with financial hardships, on average, have lower test scores
# -  The count of female students from households where parents have just had some schooling are comparable with the other counts.

# %% [markdown]
# ***Free/Reduced Lunch Affecting Average Scores***

# %%
sns.countplot(ex[ex['lunch']=='free/reduced']['Average Score'],data=ex,palette='magma')
plt.tight_layout()

# %% [markdown]
# - Assumption:
# Free/Reduced should affect the scores of students.
# - From the above graph it is quite clear that Free/Reduced eating lunch students have scored less when compared to others.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# - There were many urban Myths/Assumptions that solves here:
# -   Does Practice make one Perfect? OR
# - Assupmtion 1: Practice is the must needed thing.
# - Though the marks of students who did not compltete the syllabus was less than those who did but the difference betwwen both categories of students was not much.
# - Hence understanding of concepts is more important which all students must have done in class.
#
# - Assumption 2: Males can perform better than females.
# - The graphs and anylsis clearly states that the performance of females in every aspect is as par or better than males.
#
# - Assumption 3: Students whose parents are well educated perform well.
# - True to some extent but most of the students whose parents studied till just high school were able to score good enough though the difference between both categories was not much.
#
# - It is also not false to say that the seriousness of study that a student has defends on family background. Parents motivate Students to a great extent and play a role of idols and inspiration.
#
# - Also the performance of Minority Group E says a lot that separation on the basis of Minority and Majority Communities does not appreciately affect the performance of students. Group E performed well.
